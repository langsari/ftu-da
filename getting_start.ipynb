# %% [markdown]
# import to use pandas library

# %%
import pandas as pd

# %% [markdown]
# use read_excel to dealing with excel file

# %%
data = pd.read_excel('Superstore.xlsx')

# %% [markdown]
# save file

# %%
data.to_csv("S.csv")

# %% [markdown]
# read json file

# %%
quran_json = pd.read_json('https://raw.githubusercontent.com/langsari/quran-dataset/master/dataset/quran-json-reformat/surah/1.json')

# %%
quran_json
# Out:
#    number                                      source_tafsir  sum_ayat  \
# 1       1  Aplikasi Quran Kementrian Agama Republik Indon...         7
# 2       1  Aplikasi Quran Kementrian Agama Republik Indon...         7
# 3       1  Aplikasi Quran Kementrian Agama Republik Indon...         7
# 4       1  Aplikasi Quran Kementrian Agama Republik Indon...         7
# 5       1  Aplikasi Quran Kementrian Agama Republik Indon...         7
# 6       1  Aplikasi Quran Kementrian Agama Republik Indon...         7
# 7       1  Aplikasi Quran Kementrian Agama Republik Indon...         7
#
#                                                 ayat     name  \
# 1  {'text_tafsir_en': 'Surah al-Fatihah begins wi...  الفاتحة
# 2  {'text_tafsir_en': 'In the verse above, God be...  الفاتحة
# 3  {'text_tafsir_en': 'In verse two above Allah s...  الفاتحة
# 4  {'text_tafsir_en': 'After Allah mentions some ...  الفاتحة
# 5  {'text_tafsir_en': 'In the preceding verses ar...  الفاتحة
# ...

# %%
data
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
data.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
data.tail()
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 9421  Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9422  Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9423  Frederick Cole  Delivery Truck         Consumer        Furniture  ...
# 9424   Tammy Buckley     Express Air         Consumer        Furniture  ...
# 9425   Tammy Buckley     Express Air         Consumer  Office Supplies  ...
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
# Row ID                  9426 non-null int64
# Order Priority          9426 non-null object
# Discount                9426 non-null float64
# Unit Price              9426 non-null float64
# Shipping Cost           9426 non-null float64
# Customer ID             9426 non-null int64
# Customer Name           9426 non-null object
# Ship Mode               9426 non-null object
# Customer Segment        9426 non-null object
# Product Category        9426 non-null object
# Product Sub-Category    9426 non-null object
# Product Container       9426 non-null object
# Product Name            9426 non-null object
# Product Base Margin     9354 non-null float64
# Region                  9426 non-null object
# State or Province       9426 non-null object
# City                    9426 non-null object
# Postal Code             9426 non-null int64
# ...

# %%
data.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   9426.000000  9426.000000  9426.000000    9426.000000  9426.000000
# mean   20241.015277     0.049628    88.303686      12.795142  1738.422236
# std     6101.890965     0.031798   281.540982      17.181203   979.167197
# min        2.000000     0.000000     0.990000       0.490000     2.000000
# 25%    19330.250000     0.020000     6.480000       3.192500   898.000000
# 50%    21686.500000     0.050000    20.990000       6.050000  1750.000000
# 75%    24042.750000     0.080000    85.990000      13.990000  2578.750000
# max    26399.000000     0.250000  6783.020000     164.730000  3403.000000
#
#        Product Base Margin   Postal Code        Profit  Quantity ordered new  \
# count          9354.000000   9426.000000   9426.000000           9426.000000
# mean              0.512189  52446.327286    139.236410             13.798430
# ...

# %%
data.shape
# Out:
# (9426, 24)

# %%
data.size
# Out:
# 226224

# %%
data.index
# Out:
# RangeIndex(start=0, stop=9426, step=1)

# %%
data.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(data)
# Out:
# /Users/kholed/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/kholed/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.pairplot(data)

# %%
data["Profit"].hist
# Out:
# <bound method hist_series of 0          1.320000
# 1          4.560000
# 2        -47.640000
# 3        -30.510000
# 4        998.202300
#            ...
# 9421     137.860000
# 9422     -39.070000
# 9423   -1225.029097
# 9424     349.485000
# 9425      78.062400
# Name: Profit, Length: 9426, dtype: float64>

# %%
# %matplotlib inline
# import matplotlib.pyplot as plt
data.hist(bins=50, figsize=(20,15))
# save_fig("attribute_histogram_plots")
plt.show()
